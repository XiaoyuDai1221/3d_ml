# %%
import numpy as np
import porespy as ps
import matplotlib.pyplot as plt
ps.visualization.set_mpl_style()
np.random.seed(10)
im = np.zeros([200,200])
im = ps.generators.RSA(im, r=10)
im = ps.generators.RSA(im, r=5)
im = ps.generators.RSA(im, r=30)
#x = ps.visualization.show_3D(im)
fig, ax = plt.subplots(figsize=[7, 7]);
plt.axis(False);
plt.imshow(im);
ps.io.to_stl(im, filename='test_image2d')
